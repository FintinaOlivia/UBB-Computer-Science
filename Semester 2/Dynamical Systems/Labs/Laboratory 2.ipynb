# %%
var('t')
x = sin(t)
diff(x,t,4) - x
# Out:
# 0

# %%
var('t')
x = function('x')(t)

# %%
eq = diff(x,t,2) + x

# %%
desolve(eq,x)
# Out:
# _K2*cos(t) + _K1*sin(t)

# %%
eq = 4 * diff(x,t,2) + 8 * diff(x,t,1) + 5 * x

# %%
desolve(eq,x)
# Out:
# (_K2*cos(1/2*t) + _K1*sin(1/2*t))*e^(-t)

# %%
eq = diff(x,t,2) - 3 * diff(x,t,1) + 2 * x

# %%
desolve(eq,x)
# Out:
# _K1*e^(2*t) + _K2*e^t

# %%
eq5  = diff(x,t,1) + t * x

# %%
desolve(eq5,x)
# Out:
# _C*e^(-1/2*t^2)

# %%
eq = diff(x,t,2) + x

# %%
eq == 0
solution6 = desolve(eq, x, ics=[pi/2 , 1, -2])

# %%
plot(solution6, -10, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq7 = 4 * diff(x,t,2) + 8 * diff(x,t,1) + 5 * x
solution7 = desolve(eq7, x, ics = [0, 0, 0.5])

# %%
plot(solution7, -0.5, 1.5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq8 = diff(x,t,2) - 3 * diff(x,t,1) + 2* x

# %%
solution8 = desolve(eq8, x, ics = [0, 2, 3])

# %%
solution8
# Out:
# e^(2*t) + e^t

# %%
plot(solution8, -5, 5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
equation9 = diff(x,t,2)  + 5 * x

# %%
desolve(equation9, x)
# Out:
# _K2*cos(sqrt(5)*t) + _K1*sin(sqrt(5)*t)

# %%
equation10 = diff(x,t,2) + t * x

# %%
solution10 = desolve(equation10, x, contrib_ode = true)

# %%
eq10 = diff(x,t,2) + x

# %%
desolve(eq10, x, ics = [0, 0, pi, 0])
# Out:
# r45*sin(t)

# %%
eq10 = diff(x,t,2) + x
desolve(eq10, x, ics = [0,0,pi,0])
# Out:
# r46*sin(t)

# %% [markdown]
# eq13 = diff(x,t,1) + x
# desolve(eq13 == 15,x)

# %%
eq14 = diff(x,t,1) + x == 2*(e^t) - 7 * (e ^(-3 * t))
desolve(eq14, x)
# Out:
# 1/2*(2*_C + 2*e^(2*t) + 7*e^(-2*t))*e^(-t)

# %%
eq15 = diff(x,t,1) + x == -(t^2) + 3 * t - 7

# %%
desolve(eq15,x)
# Out:
# -((t^2 - 2*t + 2)*e^t - 3*(t - 1)*e^t - _C + 7*e^t)*e^(-t)

# %%
eq16 = diff(x,t,1) + x == sin(t) + 3 * cos(t)
solution16 = desolve(eq16,x)
solution6.factor()
# Out:
# 2*cos(t) + sin(t)

# %%
eq17 = diff(x,t,1) + x == sin(t)
solution17 = desolve(eq17,x)
solution17.factor()
# Out:
# -1/2*(cos(t)*e^t - e^t*sin(t) - 2*_C)*e^(-t)

# %%
eq18 = diff(x,t,2) + x == sin(t)
sol18 = desolve(eq18,x)
sol18.factor()
# Out:
# _K2*cos(t) - 1/2*t*cos(t) + _K1*sin(t)

# %%
eq18 = diff(x,t,1) + x == 3 * cos(t)
sol18 = desolve(eq18,x)
sol18.factor()
# Out:
# 1/2*(3*cos(t)*e^t + 3*e^t*sin(t) + 2*_C)*e^(-t)

# %%
p = sqrt(5) * cos(t - arctan(1/2))
p.trig_simplify()
# Out:
# 2*cos(t) + sin(t)
